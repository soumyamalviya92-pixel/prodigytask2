# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyamalviya92-pixel/prodigytask2/blob/main/prodigytask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers transformers accelerate torch safetensors

# %%
import torch
from diffusers import StableDiffusionPipeline

# %%
model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")

# %%
prompt = "A beautiful sunset over mountains, realistic style"

# %%
image = pipe(prompt).images[0]
image

# %%
image.save("generated_image.png")
